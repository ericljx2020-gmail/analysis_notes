# %%
import pandas as pd

# %%
df = pd.read_parquet('./[2023-06-15 00:00:00-152.58.26.0].parquet.gzip')

# %%
df.sort_values(by='total_packet_count', ascending=False).head()
# Out:
#                    time  protocol  total_packet_count
# 450 2023-06-16 14:05:00         6               11860
# 778 2023-06-17 17:25:00         6               11209
# 472 2023-06-16 15:55:00         6               10905
# 466 2023-06-16 15:25:00         6               10760
# 759 2023-06-17 15:50:00         6               10165

# %%
df_tcp = df[df['protocol'] == 6]

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(df_tcp['time'], df_tcp['total_packet_count'])

# %%
df = pd.read_parquet('./[2023-06-15 00:00:00-157.41.227.0].parquet.gzip')

# %%
df_tcp = df[df['protocol'] == 6]

# %%
plt.plot(df_tcp['time'], df_tcp['total_packet_count'])

# %%
df = pd.read_parquet('./[2023-06-15 00:00:00-157.42.200.0].parquet.gzip')

# %%
df_tcp = df[df['protocol'] == 6]

# %%
plt.plot(df_tcp['time'], df_tcp['total_packet_count'])
